# %% [markdown]
# # 🌳 Decision Tree Classifier — Quick Notes
# ---
# > **Type:** Supervised | **Task:** Classification | **Dataset:** `Social_Network_Ads`

# %% [markdown]
# ## 📌 Key Points
# - Splits data into branches using **if-else conditions**
# - No feature scaling needed
# - Easy to **visualize & interpret**
# - Prone to **overfitting** if too deep
# - Splits by **Gini Impurity** or **Entropy**

# %% [markdown]
# ## 📊 Dataset: `Social_Network_Ads`
# | Column | Role |
# |---|---|
# | `Gender`, `Age`, `EstimatedSalary` | Features (X) |
# | `Purchased` | Target (y) |

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

df = pd.read_csv("/content/Social_Network_Ads - Social_Network_Ads.csv")
lb = LabelEncoder()
df['Gender'] = lb.fit_transform(df['Gender'])

x = df.drop(columns=['Purchased'])
y = df['Purchased']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

dt = DecisionTreeClassifier(max_depth=5, min_samples_split=10, min_samples_leaf=5, random_state=42)
dt.fit(x_train, y_train)
y_pred = dt.predict(x_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
print("Feature Importances:", dict(zip(x.columns, dt.feature_importances_)))
# Out:
# Accuracy: 0.9375
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95        52
#            1       0.90      0.93      0.91        28
#
#     accuracy                           0.94        80
#    macro avg       0.93      0.94      0.93        80
# weighted avg       0.94      0.94      0.94        80
#
# Feature Importances: {'User ID': np.float64(0.019146421602950086), 'Gender': np.float64(0.0), 'Age': np.float64(0.4896221332507851), 'EstimatedSalary': np.float64(0.4912314451462647)}

# %% [markdown]
# ## ⚠️ Overfitting Controls
# | Param | Effect |
# |---|---|
# | `max_depth` | Limit tree levels |
# | `min_samples_split` | Min samples to split node |
# | `min_samples_leaf` | Min samples at leaf |
#
# ## 🥇 Remember
# - Deep tree = overfit | Shallow tree = underfit
# - Gini (default) is faster; Entropy is more info-theoretic
# - `feature_importances_` → which features matter most
